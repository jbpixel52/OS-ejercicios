# %%
from tmdbv3api import Movie, Person, TMDb
import logging
import threading
import time
from queue import Queue
tmdb = TMDb()
tmdb.api_key = 'd831e096844d9299df8c981c70143094'

tmdb.language = 'en'
tmdb.debug = False

movie = Movie()

MVIDS=[]

def get_movie(arg):
    search = movie.search(arg)
    movie_id = search[1]['id']
    overview = search[1]['overview']
    print('\n#######', search[1]['original_title'], "#######")
    print(overview)
    movie_credits = movie.credits(movie_id)
    MVIDS.append(str(movie_id))
    return movie_id


def get_cast(id):
    cast = movie.credits(id)['cast'][:1]
    print('star: ',cast[0]['name'])



if __name__ == "__main__":
    
    movie1 =threading.Thread(target=get_movie, args=('batman',))
    movie1.start()
    movie1.join()
    cast1=threading.Thread(target=get_cast, args=(MVIDS[0],))
    cast1.start()
    cast1.join()

    movie2 =threading.Thread(target=get_movie, args=('IRON MAN',))
    movie2.start()
    movie2.join()
    cast2=threading.Thread(target=get_cast, args=(MVIDS[1],))
    cast2.start()
    cast2.join()
    
    movie1 =threading.Thread(target=get_movie, args=('blade runner',))
    movie1.start()
    movie1.join()
    cast1=threading.Thread(target=get_cast, args=(MVIDS[2],))
    cast1.start()
    cast1.join()
    
    movie1 =threading.Thread(target=get_movie, args=('spirited away',))
    movie1.start()
    movie1.join()
    cast1=threading.Thread(target=get_cast, args=(MVIDS[3],))
    cast1.start()
    cast1.join()
    
    movie1 =threading.Thread(target=get_movie, args=('incredibles',))
    movie1.start()
    movie1.join()
    cast1=threading.Thread(target=get_cast, args=(MVIDS[4],))
    cast1.start()
    cast1.join()
# Out:
# ####### Batman Begins #######
# Driven by tragedy, billionaire Bruce Wayne dedicates his life to uncovering and defeating the corruption that plagues his home, Gotham City.  Unable to work within the system, he instead creates a new identity, a symbol of fear for the criminal underworld - The Batman.
# star:  Christian Bale
#
# ####### Iron Man #######
# After being held captive in an Afghan cave, billionaire engineer Tony Stark creates a unique weaponized suit of armor to fight evil.
# star:  Robert Downey Jr.
#
# ####### Blade Runner #######
# In the smog-choked dystopian Los Angeles of 2019, blade runner Rick Deckard is called out of retirement to terminate a quartet of replicants who have escaped to Earth seeking their creator for a way to extend their short life spans.
# star:  Harrison Ford
#
# ####### 千と千尋の神隠し #######
# ...
